# %% [markdown]
# <a href="https://colab.research.google.com/github/Said113/colabgoogle/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#print(dir(plt))
plt.plot([1,2,3,4],[5,6,3,8],"ro-")
plt.grid()
plt.show()

# %%
a=np.linspace(5,15,10,dtype=np.int)
plt.plot(a,pow(a,2),"go-")
plt.plot(a,np.power(a[::-1],2),"bo-")
#plt.plot(np.intersect1d())
u=np.array([[a],[a**2]])
t=np.array(((a),(a[::-1]**2)))
y=np.intersect1d(u.flatten(),t.flatten())
#here a just test if i can get the center points -_- 
#n1=np.linspace(9,10,25)
#n2=np.linspace(81,100,25)
#plt.plot(n1,n2,"*")
#plt.plot(y,"mo")
